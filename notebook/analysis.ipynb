# %% [markdown]
# Data structure

# %%
import pandas as pd
raw_data = pd.read_csv('../data/raw_data.csv')
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80775 entries, 0 to 80774
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       80775 non-null  int64
#  1   Street                   65587 non-null  object
#  2   HouseNumber              63385 non-null  object
#  3   Box                      14957 non-null  object
#  4   Floor                    31345 non-null  float64
#  5   City                     80775 non-null  object
#  6   PostalCode               80775 non-null  int64
#  7   Region                   80775 non-null  object
#  8   District                 80775 non-null  object
#  9   Province                 80775 non-null  object
#  10  PropertyType             80775 non-null  object
#  11  PropertySubType          80775 non-null  object
#  12  Price                    80773 non-null  float64
#  13  SaleType                 80775 non-null  object
# ...

# %%
raw_data.describe()
# Out:
#                  ID         Floor    PostalCode         Price  \
# count  8.077500e+04  31345.000000  80775.000000  8.077300e+04
# mean   1.097719e+07      3.708694   5212.803033  4.320739e+05
# std    2.993144e+05    237.739808   3045.581898  4.811757e+05
# min    1.882546e+06      0.000000   1000.000000  1.000000e+00
# 25%    1.092278e+07      0.000000   2300.000000  2.290000e+05
# 50%    1.107307e+07      1.000000   4728.000000  3.250000e+05
# 75%    1.114773e+07      3.000000   8400.000000  4.750000e+05
# max    1.119958e+07  41995.000000   9992.000000  2.250000e+07
#
#        BidStylePricing  ConstructionYear  BedroomCount    LivingArea  \
# count     69219.000000      49211.000000  80775.000000  71023.000000
# mean          0.088083       1978.619760      2.935438    179.064233
# std           0.283417         79.450292      2.117130    458.276481
# min           0.000000       1753.000000      0.000000      3.000000
# ...

# %%
clean_data = pd.read_csv('../data/clean_data.csv')
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65469 entries, 0 to 65468
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Floor                              65469 non-null  float64
#  1   PostalCode                         65469 non-null  float64
#  2   Price                              65469 non-null  float64
#  3   ConstructionYear                   65469 non-null  float64
#  4   LivingArea                         65469 non-null  float64
#  5   Furnished                          65469 non-null  float64
#  6   Fireplace                          65469 non-null  float64
#  7   TerraceArea                        65469 non-null  float64
#  8   GardenArea                         65469 non-null  float64
#  9   Facades                            65469 non-null  float64
#  10  SwimmingPool                       65469 non-null  float64
# ...

# %%
clean_data.describe()
# Out:
#               Floor    PostalCode         Price  ConstructionYear  \
# count  65469.000000  65469.000000  65469.000000      65469.000000
# mean       0.001582      0.453578      0.030075          0.808670
# std        0.010387      0.346162      0.032877          0.115989
# min        0.000000      0.000000      0.000000          0.000000
# 25%        0.001001      0.130116      0.016169          0.775000
# 50%        0.001001      0.344751      0.022437          0.810714
# 75%        0.001001      0.826290      0.032839          0.878571
# max        1.000000      1.000000      1.000000          1.000000
#
#          LivingArea     Furnished     Fireplace   TerraceArea    GardenArea  \
# count  65469.000000  65469.000000  65469.000000  65469.000000  65469.000000
# mean       0.003442      0.023339      0.160030      0.001398      0.000774
# std        0.006606      0.150980      0.366637      0.006560      0.007568
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = clean_data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8}) # Adjust the font size here

# Customize the plot
plt.title('Correlation Matrix of Clean Data', fontsize=16)
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels vertically
plt.yticks(rotation=0)               # Rotate y-axis labels horizontally
plt.tight_layout()

# Show the plot
plt.show()
